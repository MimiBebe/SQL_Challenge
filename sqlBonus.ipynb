# %%
from sqlalchemy import create_engine, inspect, func
from config import username, password

engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/employee_db')
connection = engine.connect()

# %%
import pandas as pd
employees = pd.read_sql('select * from employees', connection)
employees.head()
# Out:
#    emp_no emp_title  birth_date  first_name  last_name sex   hire_date
# 0  473302     s0001  1953-07-25    Hideyuki   Zallocco   M  1990-04-28
# 1  475053     e0002  1954-11-18       Byong  Delgrande   F  1991-09-07
# 2   57444     e0002  1958-01-30       Berry       Babb   F  1992-03-21
# 3  421786     s0001  1957-09-28       Xiong   Verhoeff   M  1987-11-26
# 4  282238     e0003  1952-10-28  Abdelkader    Baumann   F  1991-01-18

# %%
titles = pd.read_sql('select* from titles', connection)
titles.head()
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer

# %%
employees = pd.read_sql('select * from employees', connection)
employees.head()
# Out:
#    emp_no emp_title  birth_date  first_name  last_name sex   hire_date
# 0  473302     s0001  1953-07-25    Hideyuki   Zallocco   M  1990-04-28
# 1  475053     e0002  1954-11-18       Byong  Delgrande   F  1991-09-07
# 2   57444     e0002  1958-01-30       Berry       Babb   F  1992-03-21
# 3  421786     s0001  1957-09-28       Xiong   Verhoeff   M  1987-11-26
# 4  282238     e0003  1952-10-28  Abdelkader    Baumann   F  1991-01-18

# %%
salaries = pd.read_sql('select * from salaries',connection)
salaries.head()
# Out:
#    emp_no  salary
# 0   10001   60117
# 1   10002   65828
# 2   10003   40006
# 3   10004   40054
# 4   10005   78228

# %%
mergeTable = pd.merge(pd.merge(employees,salaries,on='emp_no'),titles,left_on='emp_title',right_on = 'title_id', how = 'left')
mergeTable.head()
# Out:
#    emp_no emp_title  birth_date  first_name  last_name sex   hire_date  \
# 0  473302     s0001  1953-07-25    Hideyuki   Zallocco   M  1990-04-28
# 1  475053     e0002  1954-11-18       Byong  Delgrande   F  1991-09-07
# 2   57444     e0002  1958-01-30       Berry       Babb   F  1992-03-21
# 3  421786     s0001  1957-09-28       Xiong   Verhoeff   M  1987-11-26
# 4  282238     e0003  1952-10-28  Abdelkader    Baumann   F  1991-01-18
#
#    salary title_id            title
# 0   40000    s0001            Staff
# 1   53422    e0002         Engineer
# 2   48973    e0002         Engineer
# 3   40000    s0001            Staff
# 4   40000    e0003  Senior Engineer

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.distplot(mergeTable.salary)
groupbyTitle.head()
plt.title('Salary distribution')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d38fa70999ec> in <module>
#       1 sns.distplot(mergeTable.salary)
# ----> 2 groupbyTitle.head()
#       3 plt.title('Salary distribution')
#
# NameError: name 'groupbyTitle' is not defined

# %%
groupbyTitle = mergeTable[["title","salary"]].groupby("title").mean()

sns.catplot(x = "title",       # x variable name
            y = "salary",       # y variable name
            data =mergeTable,     # dataframe to plot
            kind = "bar",
            height=5,    
            aspect=2) 
plt.title('Average salary by title')
groupbyTitle.head()
# Out:
#                           salary
# title
# Assistant Engineer  48564.434447
# Engineer            48535.336511
# Manager             51531.041667
# Senior Engineer     48506.799871
# Senior Staff        58550.172704

# %%
connection.close()
